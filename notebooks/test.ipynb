# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("datasets/s_embed.csv")
df2 = pd.read_csv("datasets/celeba_buffalo_l_reworked.csv")

# %%
t = 0
for i in range(len(df2)):
    t+=1
    if df2["Male"][i] ==1:
        plt.plot(df["embed_Male"][i], df["embed_not_Male"][i], "*", color='r')
    else:
        plt.plot(df["embed_Male"][i], df["embed_not_Male"][i], "*", color='b')
    if t>2000:
        break
