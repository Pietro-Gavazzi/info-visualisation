# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load datasets
df = pd.read_csv("../datasets/s_embed.csv")
df2 = pd.read_csv("../datasets/celeba_buffalo_l_reworked.csv")

import matplotlib.pyplot as plt
import pandas as pd

# Load dataset
data = df2
# Choose the embedding column to plot
embedding_column = "embedding_1"  # Replace with the actual column name you want to plot

# Plot the histogram
plt.figure(figsize=(10, 6))
plt.hist(data[embedding_column], bins=30, color='purple', alpha=0.7, edgecolor='black')

# Add titles and labels
plt.title(f"Histogram of {embedding_column}", fontsize=16)
plt.xlabel(f"{embedding_column} Values", fontsize=14)
plt.ylabel("Frequency", fontsize=14)

# Show the plot
plt.grid(axis='y', alpha=0.75)
plt.show()
